# %% [markdown]
# <a href="https://colab.research.google.com/github/muzakkialfarisi/MACHINE-LEARNING/blob/master/IBMModle1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.translate import Alignment, AlignedSent

# %%
bitext = []
bitext.append(AlignedSent(['rumah', 'ini', 'besar'], ['omah', 'kiye', 'gedhe'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['warung', 'ini', 'kecil'], ['warung', 'kiye', 'cilik'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['kebun', 'ini', 'luas'], ['kebon', 'kiye', 'jembar'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['mangga', 'ini', 'manis'], ['pelem', 'kiye', 'manis'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['pepaya', 'ini', 'pahit'], ['gandul', 'kiye', 'pait'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['di', 'sini', 'hujan'], ['nang', 'kene', 'udan'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['sedang', 'apa', 'kamu'], ['lagi', 'apa', 'kowe'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['gula', 'jawa', 'manis'], ['gula', 'jawa', 'manis'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['hari', 'ini', 'panas'], ['dina', 'kiye', 'panas'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['katak', 'sedang', 'berenang'], ['bancet', 'lagi', 'renang'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['jangan', 'seperti', 'itu'], ['aja', 'kaya', 'kuwe'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['sudah', 'makan', 'belum'], ['wes', 'mangan', 'durung'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['meja', 'makan', 'bersih'], ['meja', 'mangan', 'resik'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['katak', 'sedang', 'berenang'], ['bancet', 'lagi', 'renang'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['teh', 'hangat', 'enak'], ['teh', 'anget', 'enak'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['kamu', 'sudah', 'tidur'], ['kowe', 'wes', 'turu'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['bulan', 'desember', 'gembira'], ['wulan', 'desember', 'seneng'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['air', 'putih', 'bersih'], ['banyu', 'putih', 'resik'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['saya', 'sedang', 'mendengerkan'], ['aku', 'lagi', 'ngerungokke'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))
bitext.append(AlignedSent(['tidak', 'semudah', 'itu'], ['ora', 'segampang', 'kuwe'], Alignment( [ (0 , 0), (1 , 1), (2 , 2)] )))

# %%
from nltk.translate import IBMModel1

# %%
bitext[0].invert()
# Out:
# AlignedSent(['omah', 'kiye', 'gedhe'], ['rumah', 'ini', 'besar'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[1].invert()
# Out:
# AlignedSent(['warung', 'kiye', 'cilik'], ['warung', 'ini', 'kecil'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[2].invert()
# Out:
# AlignedSent(['kebon', 'kiye', 'jembar'], ['kebun', 'ini', 'luas'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[3].invert()
# Out:
# AlignedSent(['pelem', 'kiye', 'manis'], ['mangga', 'ini', 'manis'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[4].invert()
# Out:
# AlignedSent(['gandul', 'kiye', 'pait'], ['pepaya', 'ini', 'pahit'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[5].invert()
# Out:
# AlignedSent(['nang', 'kene', 'udan'], ['di', 'sini', 'hujan'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[5].invert()
# Out:
# AlignedSent(['nang', 'kene', 'udan'], ['di', 'sini', 'hujan'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[6].invert()
# Out:
# AlignedSent(['lagi', 'apa', 'kowe'], ['sedang', 'apa', 'kamu'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[7].invert()
# Out:
# AlignedSent(['gula', 'jawa', 'manis'], ['gula', 'jawa', 'manis'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[8].invert()
# Out:
# AlignedSent(['dina', 'kiye', 'panas'], ['hari', 'ini', 'panas'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[9].invert()
# Out:
# AlignedSent(['bancet', 'lagi', 'renang'], ['katak', 'sedang', 'berenang'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[10].invert()
# Out:
# AlignedSent(['aja', 'kaya', 'kuwe'], ['jangan', 'seperti', 'itu'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[11].invert()
# Out:
# AlignedSent(['wes', 'mangan', 'durung'], ['sudah', 'makan', 'belum'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[12].invert()
# Out:
# AlignedSent(['meja', 'mangan', 'resik'], ['meja', 'makan', 'bersih'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[13].invert()
# Out:
# AlignedSent(['bancet', 'lagi', 'renang'], ['katak', 'sedang', 'berenang'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[14].invert()
# Out:
# AlignedSent(['teh', 'anget', 'enak'], ['teh', 'hangat', 'enak'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[15].invert()
# Out:
# AlignedSent(['kowe', 'wes', 'turu'], ['kamu', 'sudah', 'tidur'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[16].invert()
# Out:
# AlignedSent(['wulan', 'desember', 'seneng'], ['bulan', 'desember', 'gembira'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[17].invert()
# Out:
# AlignedSent(['banyu', 'putih', 'resik'], ['air', 'putih', 'bersih'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[18].invert()
# Out:
# AlignedSent(['aku', 'lagi', 'ngerungokke'], ['saya', 'sedang', 'mendengerkan'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
bitext[19].invert()
# Out:
# AlignedSent(['ora', 'segampang', 'kuwe'], ['tidak', 'semudah', 'itu'], Alignment([(0, 0), (1, 1), (2, 2)]))

# %%
from nltk.translate import IBMModel1

# %%
com_ibm1 = IBMModel1(bitext, 10)

# %%
print(round(com_ibm1.translation_table["ini"]["kiye"], 3) )
# Out:
# 1.0

# %%
print(round(com_ibm1.translation_table["saya"]["aku"], 3) )
# Out:
# 0.486

# %%
print(round(com_ibm1.translation_table["besar"]["gedhe"], 3) )
# Out:
# 0.499
